# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def polynomial_curve_fitting(x,y,poly_degree,noise_std):
    noise=np.random.normal(0,noise_std,len(y))
    y_noise=y+noise
    coeff=np.polyfit(x,y_noise,poly_degree)
    poly=np.poly1d(coeff)
    return poly,y_noise
def make_plots(x,y_noise,poly):
    plt.scatter(x,y_noise)
    plt.show()
    plt.scatter(x,y_noise)
    x_line=np.linspace(min(x),max(x),100)
    plt.plot(x_line,poly(x_line),color='r')
    plt.grid()
    plt.show()
def make_prediction(x_new,poly):
    predicted_val=poly(x_new)
    return predicted_val


df=sns.load_dataset('tips')


df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
x=df['total_bill']
y=df['tip']
poly,y_noise=polynomial_curve_fitting(x,y,5,3)
for actual,noise in zip(y,y_noise):
    print(f'Actual Value: {actual} and Value with noise: {noise}')
# Out:
# Actual Value: 1.01 and Value with noise: -2.7415635712471973
# Actual Value: 1.66 and Value with noise: 4.70241953121801
# Actual Value: 3.5 and Value with noise: 1.2203681537112416
# Actual Value: 3.31 and Value with noise: 1.6026615247074423
# Actual Value: 3.61 and Value with noise: 0.5925017192261333
# Actual Value: 4.71 and Value with noise: 2.3300900784921352
# Actual Value: 2.0 and Value with noise: -0.8869756140018286
# Actual Value: 3.12 and Value with noise: 6.252162702244721
# Actual Value: 1.96 and Value with noise: 2.7544773257214192
# Actual Value: 3.23 and Value with noise: 7.75270561989597
# Actual Value: 1.71 and Value with noise: -4.925220450484038
# Actual Value: 5.0 and Value with noise: 5.438058558389965
# Actual Value: 1.57 and Value with noise: 0.11233075306838503
# Actual Value: 3.0 and Value with noise: 6.053466336579218
# Actual Value: 3.02 and Value with noise: 2.5758493298044094
# Actual Value: 3.92 and Value with noise: 4.3271279222805745
# Actual Value: 1.67 and Value with noise: 3.841223873043486
# Actual Value: 3.71 and Value with noise: 2.1251531987478836
# Actual Value: 3.5 and Value with noise: -0.38531714288589924
# Actual Value: 3.35 and Value with noise: -2.3293574850612617
# Actual Value: 4.08 and Value with noise: 3.320465859397206
# Actual Value: 2.75 and Value with noise: 6.127490072085093
# Actual Value: 2.23 and Value with noise: 1.8055005840116443
# Actual Value: 7.58 and Value with noise: 2.578821690668369
# Actual Value: 3.18 and Value with noise: -1.56377582935824
# Actual Value: 2.34 and Value with noise: -0.9625506944581046
# Actual Value: 2.0 and Value with noise: 5.4559805371361785
# Actual Value: 2.0 and Value with noise: 4.09174403808305
# Actual Value: 4.3 and Value with noise: 4.2183550231773
# Actual Value: 3.0 and Value with noise: 2.339471787615628
# Actual Value: 1.45 and Value with noise: -4.633565449997737
# Actual Value: 2.5 and Value with noise: 5.462426339121662
# Actual Value: 3.0 and Value with noise: 0.3269956107425407
# Actual Value: 2.45 and Value with noise: 1.7971033715437168
# Actual Value: 3.27 and Value with noise: 4.272929669575343
# Actual Value: 3.6 and Value with noise: 6.829122482968176
# Actual Value: 2.0 and Value with noise: -0.2820986193838655
# Actual Value: 3.07 and Value with noise: 5.845716615109925
# Actual Value: 2.31 and Value with noise: 2.912949121503262
# Actual Value: 5.0 and Value with noise: 7.131998210408977
# Actual Value: 2.24 and Value with noise: 3.343385684740877
# Actual Value: 2.54 and Value with noise: 1.8846466397878618
# Actual Value: 3.06 and Value with noise: 0.54361927820502
# Actual Value: 1.32 and Value with noise: 4.181186920419859
# Actual Value: 5.6 and Value with noise: 10.712273142545444
# Actual Value: 3.0 and Value with noise: 2.421484640583773
# Actual Value: 5.0 and Value with noise: 9.79748484519987
# Actual Value: 6.0 and Value with noise: 4.473089663712794
# Actual Value: 2.05 and Value with noise: 2.3230176891453262
# Actual Value: 3.0 and Value with noise: 6.623269058425732
# Actual Value: 2.5 and Value with noise: 2.643722923005018
# Actual Value: 2.6 and Value with noise: 7.1179648440499435
# Actual Value: 5.2 and Value with noise: 8.874108836724602
# Actual Value: 1.56 and Value with noise: 3.1431780790707666
# Actual Value: 4.34 and Value with noise: 4.564311651707751
# Actual Value: 3.51 and Value with noise: 6.889348751479831
# Actual Value: 3.0 and Value with noise: 0.03961901364580589
# Actual Value: 1.5 and Value with noise: 3.4554344317658434
# Actual Value: 1.76 and Value with noise: -3.984711445276621
# Actual Value: 6.73 and Value with noise: 9.588634824300751
# Actual Value: 3.21 and Value with noise: 0.3213943543046973
# Actual Value: 2.0 and Value with noise: 4.650172175119579
# Actual Value: 1.98 and Value with noise: 2.1822312111833093
# Actual Value: 3.76 and Value with noise: 4.5859430991106755
# Actual Value: 2.64 and Value with noise: -0.11936371556247538
# Actual Value: 3.15 and Value with noise: 3.78685723512151
# Actual Value: 2.47 and Value with noise: 4.088175746099487
# Actual Value: 1.0 and Value with noise: 3.2266088607558707
# Actual Value: 2.01 and Value with noise: -0.8086796758285315
# Actual Value: 2.09 and Value with noise: 2.183133516455824
# Actual Value: 1.97 and Value with noise: 0.2173876499581513
# Actual Value: 3.0 and Value with noise: 2.722032395973584
# Actual Value: 3.14 and Value with noise: 2.25620959903522
# Actual Value: 5.0 and Value with noise: 6.780547349531229
# Actual Value: 2.2 and Value with noise: 0.357622026299812
# Actual Value: 1.25 and Value with noise: 6.005479687351197
# Actual Value: 3.08 and Value with noise: 4.674047847538339
# Actual Value: 4.0 and Value with noise: 6.00896487342774
# Actual Value: 3.0 and Value with noise: 4.121386038446394
# Actual Value: 2.71 and Value with noise: 3.6396833572472396
# Actual Value: 3.0 and Value with noise: 2.0220805821448775
# Actual Value: 3.4 and Value with noise: 2.975039980109615
# Actual Value: 1.83 and Value with noise: 2.051120717249319
# Actual Value: 5.0 and Value with noise: 2.6330381708215183
# Actual Value: 2.03 and Value with noise: 3.5190030217167587
# Actual Value: 5.17 and Value with noise: -0.5239906632977318
# Actual Value: 2.0 and Value with noise: -0.3317505173916486
# Actual Value: 4.0 and Value with noise: 5.131142809308745
# Actual Value: 5.85 and Value with noise: 6.33140968168882
# Actual Value: 3.0 and Value with noise: 2.4529895136185833
# Actual Value: 3.0 and Value with noise: 0.08675989195515754
# Actual Value: 3.5 and Value with noise: 3.0659648377503053
# Actual Value: 1.0 and Value with noise: 0.7983117622139234
# Actual Value: 4.3 and Value with noise: 9.12409431177776
# Actual Value: 3.25 and Value with noise: -0.30216723803001866
# Actual Value: 4.73 and Value with noise: 6.045501788535599
# Actual Value: 4.0 and Value with noise: 1.4213557276086748
# Actual Value: 1.5 and Value with noise: 2.011726661501633
# Actual Value: 3.0 and Value with noise: 0.15158436321768365
# Actual Value: 1.5 and Value with noise: 4.800697674178227
# Actual Value: 2.5 and Value with noise: 1.8341105021405881
# Actual Value: 3.0 and Value with noise: 6.02210563191382
# Actual Value: 2.5 and Value with noise: 4.796344437688245
# Actual Value: 3.48 and Value with noise: 5.05995997361309
# Actual Value: 4.08 and Value with noise: 5.1683841996282105
# Actual Value: 1.64 and Value with noise: 2.7939750588575745
# Actual Value: 4.06 and Value with noise: 0.27226863697586356
# Actual Value: 4.29 and Value with noise: 4.073939972609153
# Actual Value: 3.76 and Value with noise: 4.999054933180224
# Actual Value: 4.0 and Value with noise: 3.9250465029630273
# Actual Value: 3.0 and Value with noise: 1.2851030460013328
# Actual Value: 1.0 and Value with noise: -2.0804596662692614
# Actual Value: 4.0 and Value with noise: 4.4244135603314705
# Actual Value: 2.55 and Value with noise: 5.176530845589118
# Actual Value: 4.0 and Value with noise: 0.4299381979136703
# Actual Value: 3.5 and Value with noise: 2.4405535796536393
# Actual Value: 5.07 and Value with noise: 4.621544325595173
# Actual Value: 1.5 and Value with noise: 1.4345563576283005
# Actual Value: 1.8 and Value with noise: 6.615711819743082
# Actual Value: 2.92 and Value with noise: 8.69510963354589
# Actual Value: 2.31 and Value with noise: 0.14607475167455508
# Actual Value: 1.68 and Value with noise: 0.6813111489238372
# Actual Value: 2.5 and Value with noise: 1.5068571267682316
# Actual Value: 2.0 and Value with noise: 0.8010003656574811
# Actual Value: 2.52 and Value with noise: 7.869459792907339
# Actual Value: 4.2 and Value with noise: 2.050588683946494
# Actual Value: 1.48 and Value with noise: -0.00971819630016224
# Actual Value: 2.0 and Value with noise: -0.8108082675035511
# Actual Value: 2.0 and Value with noise: 3.0501658593158307
# Actual Value: 2.18 and Value with noise: 3.5206698128040843
# Actual Value: 1.5 and Value with noise: 5.632654133210858
# Actual Value: 2.83 and Value with noise: 5.73955962721671
# Actual Value: 1.5 and Value with noise: 1.3859051812319012
# Actual Value: 2.0 and Value with noise: 2.9099566210784857
# Actual Value: 3.25 and Value with noise: 3.192779297077077
# Actual Value: 1.25 and Value with noise: -0.5122263236445783
# Actual Value: 2.0 and Value with noise: 1.0589097929579367
# Actual Value: 2.0 and Value with noise: 0.6063682466733555
# Actual Value: 2.0 and Value with noise: 5.283984720102246
# Actual Value: 2.75 and Value with noise: -0.5848353044805861
# Actual Value: 3.5 and Value with noise: 1.479103127091037
# Actual Value: 6.7 and Value with noise: 11.626877303953387
# Actual Value: 5.0 and Value with noise: 3.3489535381322035
# Actual Value: 5.0 and Value with noise: 3.198078646696862
# Actual Value: 2.3 and Value with noise: 3.3739624435452518
# Actual Value: 1.5 and Value with noise: 3.269272172555008
# Actual Value: 1.36 and Value with noise: -1.0425490383164517
# Actual Value: 1.63 and Value with noise: -0.712175899921049
# Actual Value: 1.73 and Value with noise: 1.4363345308953064
# Actual Value: 2.0 and Value with noise: 3.0702501649669793
# Actual Value: 2.5 and Value with noise: 5.480270457386346
# Actual Value: 2.0 and Value with noise: -0.781538660089629
# Actual Value: 2.74 and Value with noise: 1.7414517003696768
# Actual Value: 2.0 and Value with noise: 1.7544190920867766
# Actual Value: 2.0 and Value with noise: -2.773601418881989
# Actual Value: 5.14 and Value with noise: 6.9202152652285776
# Actual Value: 5.0 and Value with noise: 4.346050121552572
# Actual Value: 3.75 and Value with noise: 0.09385537919821951
# Actual Value: 2.61 and Value with noise: 4.396762852937136
# Actual Value: 2.0 and Value with noise: 1.9547868827905683
# Actual Value: 3.5 and Value with noise: 5.680712879397088
# Actual Value: 2.5 and Value with noise: 3.417247830558945
# Actual Value: 2.0 and Value with noise: 4.683592507231168
# Actual Value: 2.0 and Value with noise: 2.071089283885645
# Actual Value: 3.0 and Value with noise: 7.5451048677669466
# Actual Value: 3.48 and Value with noise: 5.966193302129335
# Actual Value: 2.24 and Value with noise: 5.3886510418851685
# Actual Value: 4.5 and Value with noise: 1.7411751876361459
# Actual Value: 1.61 and Value with noise: 3.970209634401307
# Actual Value: 2.0 and Value with noise: 3.6792002746283807
# Actual Value: 10.0 and Value with noise: 10.572939627614941
# Actual Value: 3.16 and Value with noise: 0.4028805925490735
# Actual Value: 5.15 and Value with noise: 7.225054680025008
# Actual Value: 3.18 and Value with noise: 2.8126257620196924
# Actual Value: 4.0 and Value with noise: 2.2933902685063607
# Actual Value: 3.11 and Value with noise: 2.2592236070161666
# Actual Value: 2.0 and Value with noise: -2.362601722938882
# Actual Value: 2.0 and Value with noise: 1.3529174443298473
# Actual Value: 4.0 and Value with noise: 4.102215726026649
# Actual Value: 3.55 and Value with noise: 2.993898372393651
# Actual Value: 3.68 and Value with noise: 3.3718999686455278
# Actual Value: 5.65 and Value with noise: 7.430494026245376
# Actual Value: 3.5 and Value with noise: 2.3474463629728963
# Actual Value: 6.5 and Value with noise: 4.7624313918198515
# Actual Value: 3.0 and Value with noise: 2.3211753393645655
# Actual Value: 5.0 and Value with noise: 6.580508184085419
# Actual Value: 3.5 and Value with noise: 0.10289669582026262
# Actual Value: 2.0 and Value with noise: 2.48011699459786
# Actual Value: 3.5 and Value with noise: 1.6466285289856661
# Actual Value: 4.0 and Value with noise: 1.4287064460666308
# Actual Value: 1.5 and Value with noise: 3.97884077128397
# Actual Value: 4.19 and Value with noise: -0.8048403015047425
# Actual Value: 2.56 and Value with noise: -0.421847016722122
# Actual Value: 2.02 and Value with noise: 0.40719646639134544
# Actual Value: 4.0 and Value with noise: 5.922774602363315
# Actual Value: 1.44 and Value with noise: 4.601865164713281
# Actual Value: 2.0 and Value with noise: 3.7548133009659734
# Actual Value: 5.0 and Value with noise: 4.600163916759042
# Actual Value: 2.0 and Value with noise: 6.022993841922969
# Actual Value: 2.0 and Value with noise: 1.1992396555466636
# Actual Value: 4.0 and Value with noise: 3.6979932306636187
# Actual Value: 2.01 and Value with noise: 1.7599836420007127
# Actual Value: 2.0 and Value with noise: 7.031618410364732
# Actual Value: 2.5 and Value with noise: 5.054424605679393
# Actual Value: 4.0 and Value with noise: 0.5234188262987991
# Actual Value: 3.23 and Value with noise: -0.3497061246401141
# Actual Value: 3.41 and Value with noise: 4.578320371407238
# Actual Value: 3.0 and Value with noise: -1.9923011607388563
# Actual Value: 2.03 and Value with noise: -1.577794868652775
# Actual Value: 2.23 and Value with noise: 3.7609531142185517
# Actual Value: 2.0 and Value with noise: 2.755559421018517
# Actual Value: 5.16 and Value with noise: 4.8009457004494305
# Actual Value: 9.0 and Value with noise: 7.375857298314336
# Actual Value: 2.5 and Value with noise: 0.7605911125042903
# Actual Value: 6.5 and Value with noise: 1.282363705637393
# Actual Value: 1.1 and Value with noise: 1.5281350946715142
# Actual Value: 3.0 and Value with noise: 3.156706472050518
# Actual Value: 1.5 and Value with noise: 3.892617207333901
# Actual Value: 1.44 and Value with noise: 0.6585118525180838
# Actual Value: 3.09 and Value with noise: 3.393975174171632
# Actual Value: 2.2 and Value with noise: -3.9274680676627662
# Actual Value: 3.48 and Value with noise: 5.711586446860268
# Actual Value: 1.92 and Value with noise: -0.7942168159884946
# Actual Value: 3.0 and Value with noise: 8.804532368603649
# Actual Value: 1.58 and Value with noise: -1.5788948675448702
# Actual Value: 2.5 and Value with noise: 5.128829391498934
# Actual Value: 2.0 and Value with noise: 5.946224581889241
# Actual Value: 3.0 and Value with noise: 4.936568716621701
# Actual Value: 2.72 and Value with noise: 3.2498461738652153
# Actual Value: 2.88 and Value with noise: 2.892012934429367
# Actual Value: 2.0 and Value with noise: 8.03534937013309
# Actual Value: 3.0 and Value with noise: 0.05398889211419977
# Actual Value: 3.39 and Value with noise: 4.523255945855141
# Actual Value: 1.47 and Value with noise: 5.06508399543524
# Actual Value: 3.0 and Value with noise: 5.924321936990395
# Actual Value: 1.25 and Value with noise: 7.512603759498386
# Actual Value: 1.0 and Value with noise: -1.1505521113502
# Actual Value: 1.17 and Value with noise: -0.5595922756506577
# Actual Value: 4.67 and Value with noise: 0.11892623663117874
# Actual Value: 5.92 and Value with noise: 8.519150680003227
# Actual Value: 2.0 and Value with noise: -1.301055794222278
# Actual Value: 2.0 and Value with noise: 5.211108583589745
# Actual Value: 1.75 and Value with noise: 0.3651494674245741
# Actual Value: 3.0 and Value with noise: 6.46222743135054

# %%
make_plots(x,y_noise,poly)


x_new=10
print(make_prediction(x_new,poly))
# Out:
# 2.2911140963256322
